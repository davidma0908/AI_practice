# %% [markdown]
# # Mercari Price Data Cleaning
#
# ![](https://cdn-images-1.medium.com/max/1600/1*jX6Gwn1rt4da7e-yUj84IQ.png)
#
# -  Mercari, Japan’s biggest community-powered shopping app, knows this problem deeply. They’d like to __offer pricing suggestions to sellers__, but this is tough because their sellers are enabled to put just about anything, or any bundle of things, on Mercari's marketplace.

# %%
import numpy as np
import pandas as pd

import string
import re

import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight') 

import gc
gc.enable()

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 讀取檔案

# %%
PATH = 'data/'
test = pd.read_table(PATH + 'test.tsv',  engine='c')
train = pd.read_table(PATH + 'train.tsv',  engine='c')

# %% [markdown]
# ## 文字統計

# %%
from collections import Counter
import time

# %%
start_time = time.time()
total_counts = Counter()
merge = pd.concat([train, test])
for i in range(test.shape[0]):
    for word in test['item_description'][i].lower().split(' '):
        total_counts[word] += 1
print('[{}] Sec Finished!'.format(round(time.time() - start_time,3)))
# Out:
# [18.744] Sec Finished!

# %% [markdown]
# ## item_description 到底有什麼東西
# `most_common` : 多到少排序

# %%
total_counts.most_common()
# Out:
# [('and', 392764),
#  ('the', 302872),
#  ('a', 263210),
#  ('for', 252534),
#  ('in', 230538),
#  ('to', 221503),
#  ('with', 215514),
#  ('is', 201711),
#  ('size', 185275),
#  ('new', 180537),
#  ('of', 161513),
#  ('no', 141492),
#  ('i', 132754),
#  ('on', 124583),
#  ('brand', 116848),
#  ('free', 111454),
#  ('you', 107807),
#  ('or', 96961),
#  ('are', 94798),
#  ('it', 92581),
#  ('this', 86853),
#  ('[rm]', 79646),
#  ('my', 76569),
#  ('will', 74101),
#  ('-', 73060),
#  ('never', 72228),
#  ('but', 71237),
#  ('all', 69196),
#  ('shipping', 68169),
#  ('great', 67796),
#  ('worn', 66158),
#  ('have', 65478),
#  ('not', 65165),
#  ('used', 64296),
#  ('from', 63872),
#  ('black', 59503),
#  ('your', 59246),
#  ('&', 57079),
#  ('price', 55202),
#  ('condition', 54178),
#  ('be', 53794),
#  ('as', 51394),
#  ('2', 51276),
#  ('has', 51139),
#  ('one', 50848),
#  ('like', 49800),
#  ('please', 48248),
#  ('only', 47662),
#  ('good', 46954),
#  ('bundle', 46859),
#  ('can', 45995),
#  ('1', 45904),
#  ('pink', 45629),
#  ('if', 43049),
#  ('very', 41932),
#  ('description', 41166),
#  ('small', 40686),
#  ('out', 40172),
#  ('me', 39575),
#  ('so', 39477),
#  ('yet', 39447),
#  ('that', 38747),
#  ('other', 37109),
#  ('condition.', 36864),
#  ('just', 36751),
#  ('any', 35810),
#  ('color', 35492),
#  ('3', 34647),
#  ('these', 32996),
#  ('perfect', 32518),
#  (',', 32412),
#  ('more', 32130),
#  ('white', 31210),
#  ('box', 31100),
#  ('comes', 30743),
#  ('at', 30034),
#  ('super', 29958),
#  ('they', 29441),
#  ('items', 29103),
#  ('up', 28143),
#  ('blue', 27409),
#  ('by', 26896),
#  ('been', 26886),
#  ('ship', 26346),
#  ('cute', 26307),
#  ('firm', 24983),
#  ('tags', 24973),
#  ('fit', 24468),
#  ('medium', 24252),
#  ('still', 23840),
#  ('an', 23740),
#  ('iphone', 23731),
#  ('top', 23617),
#  ('large', 23515),
#  ('smoke', 23361),
#  ('4', 23357),
#  ('•', 22698),
#  ("it's", 22492),
#  ('6', 22269),
#  ("don't", 21742),
#  ('wear', 21716),
#  ('some', 21649),
#  ('check', 21559),
#  ('back', 21473),
#  ('authentic', 21350),
#  ('excellent', 21350),
#  ('do', 21338),
#  ('100%', 21158),
#  ('make', 20665),
#  ('get', 20585),
#  ('x', 20394),
#  (':)', 20061),
#  ('light', 20030),
#  ('once', 19821),
#  ('/', 19694),
#  ('see', 19360),
#  ('gold', 19335),
#  ('save', 19269),
#  ('also', 18811),
#  ('set', 18643),
#  ('fits', 18635),
#  ('case', 18392),
#  ('.', 18348),
#  ('ask', 18130),
#  ('before', 18124),
#  ('long', 18101),
#  ('secret', 18099),
#  ('them', 17959),
#  ('little', 17810),
#  ('5', 17807),
#  ('original', 17794),
#  ('item', 17543),
#  ('day', 17294),
#  ('soft', 16814),
#  ('two', 16671),
#  ('new,', 16595),
#  ('high', 16412),
#  ('use', 16364),
#  ('off', 16333),
#  ('made', 16299),
#  ('7', 16119),
#  ('few', 16100),
#  ('beautiful', 16061),
#  ('each', 15851),
#  ('both', 15655),
#  ('new.', 15613),
#  ('*', 15611),
#  ('full', 15572),
#  ('bag', 15490),
#  ('plus', 15319),
#  ('bought', 15159),
#  ('home', 14899),
#  ('was', 14721),
#  ('dress', 14694),
#  ('red', 14382),
#  ('too', 14370),
#  ('includes', 13802),
#  ('body', 13794),
#  ('silver', 13759),
#  ('about', 13711),
#  ('when', 13530),
#  ('nike', 13386),
#  ('8', 13313),
#  ("women's", 13113),
#  ('shipping.', 13083),
#  ('front', 12971),
#  ('green', 12919),
#  ('home.', 12917),
#  ("victoria's", 12755),
#  ('shirt', 12698),
#  ('colors', 12643),
#  ('look', 12599),
#  ('than', 12563),
#  ('same', 12383),
#  ('buy', 12377),
#  ('nwt', 12371),
#  ('pet', 12370),
#  ('without', 12306),
#  ('available', 12288),
#  ('listing', 12259),
#  ('oz', 12243),
#  ('thank', 12228),
#  ("i'm", 12120),
#  ('there', 12016),
#  ('size:', 12015),
#  ('shipping!', 11837),
#  ('questions', 11829),
#  ('need', 11815),
#  ('would', 11746),
#  ('listings', 11741),
#  ('lularoe', 11680),
#  ('works', 11607),
#  ('come', 11580),
#  ('we', 11563),
#  ('want', 11556),
#  ('retail', 11547),
#  ('leggings', 11521),
#  ('quality', 11513),
#  ('used.', 11462),
#  ('10', 11456),
#  ('times', 11453),
#  ('love', 11365),
#  ('skin', 11243),
#  ('tag', 11224),
#  ('condition!', 11195),
#  ('pair', 11161),
#  ('worn.', 11087),
#  ('leather', 11000),
#  ('selling', 10982),
#  ('feel', 10925),
#  ('know', 10817),
#  ('dark', 10727),
#  ('phone', 10718),
#  ('time', 10642),
#  ('condition,', 10635),
#  ('included', 10606),
#  ('what', 10492),
#  ('inches', 10428),
#  ('inside', 10380),
#  ('message', 10352),
#  ('after', 10225),
#  ('take', 10211),
#  ('over', 10195),
#  ('style', 10164),
#  ('fast', 9967),
#  ('lip', 9925),
#  ('let', 9890),
#  ('baby', 9876),
#  ('bottom', 9799),
#  ('grey', 9746),
#  ('vs', 9726),
#  ('navy', 9719),
#  ('new!', 9716),
#  ('stains', 9704),
#  ('package', 9700),
#  ('gift', 9630),
#  ("men's", 9625),
#  ('!', 9403),
#  ('because', 9377),
#  ('purchase', 9373),
#  ('brush', 9362),
#  ('days', 9331),
#  ('last', 9330),
#  ('sleeve', 9315),
#  ('gently', 9315),
#  ('makeup', 9253),
#  ('lace', 9214),
#  ('really', 9201),
#  ('within', 9192),
#  ('purple', 9188),
#  ('picture', 9184),
#  ('box.', 9128),
#  ('waist', 9081),
#  ('+', 9058),
#  ('gray', 9028),
#  ('mini', 8970),
#  ('it.', 8888),
#  ('which', 8868),
#  ('color:', 8841),
#  ('am', 8834),
#  ('retails', 8798),
#  ('lot', 8739),
#  ('xl', 8684),
#  ('may', 8628),
#  ('purchased', 8584),
#  ('next', 8552),
#  ('brown', 8530),
#  ('around', 8455),
#  ('matte', 8451),
#  ('bra', 8402),
#  ('first', 8364),
#  ('our', 8317),
#  ('[rm].', 8308),
#  ('shown', 8262),
#  ('sure', 8261),
#  ('tags.', 8212),
#  ('sold', 8195),
#  ('side', 8190),
#  ('hair', 8173),
#  ('offers', 8156),
#  ('print', 8107),
#  ('shoes', 8101),
#  ('business', 8076),
#  ('flaws', 8022),
#  ('times.', 7982),
#  ('shorts', 7929),
#  ('sealed', 7902),
#  ('washed', 7895),
#  ('once.', 7858),
#  ('thanks', 7858),
#  ('most', 7836),
#  (':', 7794),
#  ('extra', 7788),
#  ('small.', 7754),
#  ('does', 7726),
#  ('design', 7695),
#  ('adjustable', 7690),
#  ('clean', 7685),
#  ('xs', 7683),
#  ('different', 7678),
#  ('material', 7654),
#  ('easy', 7629),
#  ('under', 7610),
#  ('ships', 7604),
#  ('best', 7598),
#  ('length', 7581),
#  ('jeans', 7581),
#  ('american', 7567),
#  ('shipped', 7559),
#  ('wore', 7503),
#  ('9', 7488),
#  ('firm.', 7472),
#  ('big', 7439),
#  ('zip', 7432),
#  ('12', 7412),
#  ('pictures', 7369),
#  ('product', 7348),
#  ('nice', 7340),
#  ('how', 7337),
#  ('go', 7309),
#  ('couple', 7229),
#  ('sizes', 7226),
#  ('eye', 7157),
#  ('pocket', 7079),
#  ('hard', 7071),
#  ('pants', 7050),
#  ('pretty', 6980),
#  ('cotton', 6947),
#  ('water', 6903),
#  ('cream', 6898),
#  ('everything', 6866),
#  ('piece', 6805),
#  ('zipper', 6768),
#  ('low', 6766),
#  ('opened', 6706),
#  ('open', 6691),
#  ('keep', 6679),
#  ('tags:', 6672),
#  ('prices', 6632),
#  ('well', 6615),
#  ('work', 6586),
#  ('hot', 6573),
#  ('face', 6564),
#  ('rose', 6548),
#  ('got', 6539),
#  ('note', 6516),
#  ('its', 6509),
#  ('tank', 6506),
#  ('vintage', 6496),
#  ('offer', 6490),
#  ('looks', 6481),
#  ('left', 6478),
#  ('comment', 6462),
#  ('color.', 6433),
#  ('m', 6366),
#  ('logo', 6326),
#  ('add', 6318),
#  ('victoria', 6313),
#  ('pockets', 6310),
#  ('us', 6299),
#  ('wash', 6285),
#  ('apple', 6275),
#  ('medium.', 6268),
#  ('minor', 6246),
#  ('me.', 6205),
#  ('many', 6196),
#  ('comfortable', 6193),
#  ('sale', 6185),
#  ('button', 6167),
#  ('find', 6122),
#  ('jacket', 6106),
#  ('right', 6067),
#  ('screen', 6067),
#  ('sell', 6060),
#  ('glass', 6018),
#  ('happy', 5967),
#  ('hand', 5960),
#  ('palette', 5937),
#  ('gorgeous', 5915),
#  ('game', 5904),
#  ('usps', 5896),
#  ('read', 5885),
#  ('tracking', 5874),
#  ('pairs', 5871),
#  ('looking', 5858),
#  ('card', 5856),
#  ('always', 5853),
#  ('floral', 5853),
#  ('24', 5853),
#  ('could', 5847),
#  ('even', 5829),
#  ('strap', 5823),
#  ('clear', 5768),
#  ('plastic', 5765),
#  ('scratches', 5745),
#  ('signs', 5729),
#  ('natural', 5695),
#  ('tried', 5672),
#  ('liquid', 5661),
#  ('yellow', 5625),
#  ('true', 5592),
#  ('charger', 5531),
#  ('limited', 5526),
#  ('ring', 5522),
#  ('were', 5521),
#  ('closet', 5506),
#  ('receive', 5489),
#  ('short', 5475),
#  ('while', 5475),
#  ('contact', 5473),
#  ('lipstick', 5454),
#  ('pic', 5449),
#  ('shade', 5414),
#  ('size.', 5411),
#  ('cover', 5403),
#  ('shoulder', 5402),
#  ('old', 5377),
#  ('much', 5368),
#  ('beauty', 5366),
#  ('order', 5347),
#  ('down', 5340),
#  ('forever', 5338),
#  ('three', 5326),
#  ('unless', 5323),
#  ('packaging', 5318),
#  ('paid', 5313),
#  ('edition', 5306),
#  ('bath', 5256),
#  ('months', 5256),
#  ('hold', 5255),
#  ('girls', 5240),
#  ('originally', 5238),
#  ('pack', 5234),
#  ('give', 5143),
#  ('christmas', 5143),
#  ('cut', 5140),
#  ('barely', 5138),
#  ('pink,', 5124),
#  ('longer', 5109),
#  ('way', 5104),
#  ('30', 5102),
#  ('l', 5101),
#  ('then', 5096),
#  ('holds', 5085),
#  ('sz', 5058),
#  ('every', 5036),
#  ('girl', 5008),
#  ('necklace', 5003),
#  ('dry', 4973),
#  ('into', 4966),
#  ('mint', 4950),
#  ('discount', 4944),
#  ('hours', 4933),
#  ('care', 4931),
#  ('urban', 4923),
#  ('lots', 4922),
#  ('orange', 4919),
#  ('life', 4872),
#  ('fabric', 4842),
#  ('weight', 4834),
#  ("doesn't", 4824),
#  ('disney', 4822),
#  ('inch', 4821),
#  ('boots', 4809),
#  ('kids', 4805),
#  ('wear.', 4800),
#  ('stretchy', 4798),
#  ('=', 4796),
#  ('show', 4771),
#  ('fl', 4768),
#  ('bundles', 4754),
#  ('air', 4743),
#  ('galaxy', 4740),
#  ('bag.', 4732),
#  ('bottle', 4721),
#  ('photo', 4696),
#  ('total', 4683),
#  ('back.', 4671),
#  ('band', 4660),
#  ('pieces', 4651),
#  ('large.', 4646),
#  ('nwot', 4624),
#  ('travel', 4602),
#  ('used,', 4597),
#  ('(', 4581),
#  ('features', 4567),
#  ('steel', 4563),
#  ('holes', 4562),
#  ('samsung', 4551),
#  ('worn,', 4537),
#  ('cases', 4535),
#  ('store', 4529),
#  ('due', 4511),
#  ('sexy', 4503),
#  ('sweater', 4498),
#  ('warm', 4497),
#  ('powder', 4496),
#  ('straps', 4492),
#  ('eyeshadow', 4480),
#  ('put', 4434),
#  ('included.', 4432),
#  ('through', 4387),
#  ('21', 4380),
#  ('them.', 4377),
#  ('rae', 4374),
#  ('now', 4371),
#  ('shape', 4341),
#  ('listed', 4317),
#  ('s', 4310),
#  ('bit', 4294),
#  ('says', 4291),
#  ('had', 4281),
#  ('additional', 4281),
#  ('missing', 4279),
#  ('twice', 4274),
#  ('amazing', 4272),
#  ('rips', 4240),
#  ('♡', 4217),
#  ('dunn', 4216),
#  ('measures', 4209),
#  ('metal', 4188),
#  ('bubble', 4186),
#  ('ipad', 4173),
#  ('michael', 4168),
#  ('sterling', 4164),
#  ('include', 4162),
#  ('classic', 4161),
#  ('tee', 4149),
#  ('collection', 4147),
#  ('includes:', 4144),
#  ('oil', 4142),
#  ('per', 4139),
#  ('black,', 4101),
#  ('usb', 4100),
#  ('purse', 4085),
#  ('cable', 4077),
#  ('boys', 4075),
#  ('stretch', 4051),
#  ('neck', 4050),
#  ('real', 4043),
#  ('polyester', 4043),
#  ('summer', 4029),
#  ('jewelry', 4001),
#  ("didn't", 3969),
#  ('adorable', 3965),
#  ('try', 3958),
#  ('tall', 3945),
#  ('orders', 3937),
#  ('watch', 3926),
#  ('hoodie', 3925),
#  ('os', 3903),
#  ('combine', 3890),
#  ('rare', 3890),
#  ('20', 3883),
#  ('kit', 3883),
#  ('ready', 3874),
#  ('blue,', 3873),
#  ('battery', 3863),
#  ('women', 3849),
#  ('leggings.', 3840),
#  ('flaws.', 3821),
#  ('fashion', 3816),
#  ('coach', 3811),
#  ('stickers', 3806),
#  ('slight', 3790),
#  ('touch', 3790),
#  ('comfy', 3787),
#  ('foundation', 3786),
#  ('their', 3786),
#  ('help', 3783),
#  ('photos', 3760),
#  ('kylie', 3753),
#  ('lower', 3749),
#  ('multiple', 3747),
#  ('slightly', 3742),
#  ('page', 3720),
#  ('gel', 3715),
#  ('skirt', 3707),
#  ('lowest', 3699),
#  ('top.', 3686),
#  ('stainless', 3685),
#  ('bracelet', 3670),
#  ('lightweight', 3664),
#  ('double', 3661),
#  ('makes', 3657),
#  ('you.', 3655),
#  ('shoe', 3650),
#  ('better', 3648),
#  ('deep', 3631),
#  ('slime', 3624),
#  ('pop', 3617),
#  ('custom', 3599),
#  ('colored', 3595),
#  ('price.', 3580),
#  ('fun', 3571),
#  ('6s', 3550),
#  ('products', 3544),
#  ('here', 3541),
#  ('online', 3524),
#  ('half', 3523),
#  ('15', 3522),
#  ('cards', 3513),
#  ('chain', 3512),
#  ('sleeves', 3504),
#  ('adidas', 3488),
#  ('***', 3486),
#  ('lightly', 3482),
#  ('~', 3471),
#  ('heart', 3466),
#  ('send', 3460),
#  ('tc', 3454),
#  ("i'll", 3451),
#  ('being', 3427),
#  ("can't", 3424),
#  ('elastic', 3420),
#  ('almost', 3412),
#  ('matching', 3403),
#  ('wallet', 3402),
#  ('nail', 3398),
#  ('since', 3392),
#  ('another', 3391),
#  ('11', 3391),
#  ('kors', 3377),
#  ('dog', 3366),
#  ('skinny', 3366),
#  ('awesome', 3358),
#  ('faux', 3356),
#  ('authentic.', 3354),
#  ('solid', 3348),
#  ('compatible', 3343),
#  ('play', 3342),
#  (')', 3341),
#  ('brandy', 3337),
#  ('shades', 3334),
#  ('lululemon', 3323),
#  ('part', 3322),
#  ('cool', 3322),
#  ('stain', 3317),
#  ('needs', 3315),
#  ('on.', 3311),
#  ('wide', 3311),
#  ('number', 3305),
#  ('closure', 3304),
#  ('willing', 3303),
#  ('rate', 3297),
#  ('power', 3289),
#  ('flat', 3271),
#  ('games', 3266),
#  ('dress.', 3264),
#  ('regular', 3264),
#  ('shows', 3262),
#  ('maybe', 3260),
#  ('taken', 3258),
#  ('glitter', 3254),
#  ('tan', 3238),
#  ('working', 3235),
#  ('pay', 3225),
#  ('edge', 3223),
#  ('18', 3215),
#  ('must', 3214),
#  ('cup', 3214),
#  ('pics', 3204),
#  ('gloss', 3190),
#  ("i've", 3185),
#  ('dust', 3184),
#  ('nothing', 3172),
#  ('bright', 3169),
#  ('you!', 3162),
#  ('unopened', 3158),
#  ('loose', 3156),
#  ('items.', 3151),
#  ('star', 3149),
#  ('sports', 3143),
#  ('purchase.', 3142),
#  ('save!', 3139),
#  ('money', 3136),
#  ('ipod', 3134),
#  ('padded', 3132),
#  ('waterproof', 3121),
#  ('1/2', 3104),
#  ('swatched', 3091),
#  ('1x', 3082),
#  ('case.', 3081),
#  ('choose', 3078),
#  ('once,', 3076),
#  ('leave', 3073),
#  ('reasonable', 3072),
#  ('day.', 3068),
#  ('mask', 3059),
#  ('eagle', 3055),
#  ('normal', 3052),
#  ('damage', 3041),
#  ('handmade', 3031),
#  ('toddler', 3029),
#  ('earrings', 3027),
#  ('seen', 3026),
#  ('bnwt', 3026),
#  ('box,', 3012),
#  ('**', 3012),
#  ('material:', 3007),
#  ('runs', 3002),
#  ('material.', 2997),
#  ('unicorn', 2995),
#  ('smooth', 2994),
#  ('brand:', 2977),
#  ('14', 2975),
#  ('mesh', 2965),
#  ('fall', 2962),
#  ('tested', 2955),
#  ('marks', 2954),
#  ('car', 2950),
#  ("they're", 2948),
#  ('unique', 2948),
#  ('2-3', 2948),
#  ('wrong', 2944),
#  ('set.', 2941),
#  ('16', 2939),
#  ("you're", 2934),
#  ('tie', 2922),
#  ('cute!', 2919),
#  ('euc', 2918),
#  ('trades', 2912),
#  ('complete', 2912),
#  ('10%', 2909),
#  ('purchasing', 2893),
#  ('less', 2893),
#  ('easily', 2890),
#  ('create', 2888),
#  ('crop', 2886),
#  ('details', 2879),
#  ('w', 2878),
#  ('hat', 2878),
#  ('denim', 2877),
#  ('push', 2869),
#  ('bottoms', 2862),
#  ('lotion', 2859),
#  ('using', 2859),
#  ('charging', 2857),
#  ('twice.', 2853),
#  ('already', 2852),
#  ('silicone', 2846),
#  ('w/', 2842),
#  ('unused', 2834),
#  ('2.', 2831),
#  ('condition:', 2831),
#  ('ultra', 2827),
#  ('including', 2822),
#  ('shirt.', 2813),
#  ('pro', 2810),
#  ('belt', 2809),
#  ('people', 2808),
#  ('t', 2808),
#  ('protection', 2806),
#  ('✨', 2800),
#  ('her', 2793),
#  ('lashes', 2792),
#  ('wrap', 2786),
#  ('otherwise', 2785),
#  ('teal', 2784),
#  ('anything', 2781),
#  ('special', 2778),
#  ('fragrance', 2774),
#  ('tag.', 2769),
#  ('post', 2765),
#  ('men', 2765),
#  ('spandex', 2763),
#  ('bluetooth', 2763),
#  ('u', 2757),
#  ('pictured', 2755),
#  ('thick', 2753),
#  ('book', 2746),
#  ('favorite', 2742),
#  ('jordan', 2737),
#  ('who', 2737),
#  ('worn!', 2735),
#  ('second', 2729),
#  ('finish', 2729),
#  ('picture.', 2728),
#  ('pattern', 2727),
#  ('cross', 2706),
#  ('deal', 2702),
#  ('(1)', 2701),
#  ('100', 2697),
#  ('class', 2690),
#  ('well.', 2686),
#  ('stains.', 2682),
#  ('shipping,', 2677),
#  ('oz.', 2677),
#  ("that's", 2674),
#  ('apply', 2672),
#  ('helps', 2666),
#  ('bundle.', 2665),
#  ('night', 2664),
#  ('name', 2661),
#  ('only.', 2658),
#  ('polo', 2656),
#  ('durable', 2648),
#  ('wearing', 2647),
#  ('protector', 2645),
#  ('below', 2642),
#  ('profile', 2640),
#  ('wall', 2638),
#  ('own', 2638),
#  ('times,', 2638),
#  ('beige', 2635),
#  ('nude', 2635),
#  ('suede', 2635),
#  ('bikini', 2635),
#  ('fine', 2632),
#  ('run', 2630),
#  ('shadow', 2629),
#  ('lined', 2628),
#  ('black.', 2628),
#  ('small,', 2627),
#  ('slip', 2624),
#  ('came', 2623),
#  ('fleece', 2621),
#  ('tiny', 2618),
#  ('discounts', 2615),
#  ('firm!', 2613),
#  ('fit.', 2603),
#  ('4.', 2597),
#  ('scent', 2588),
#  ('out.', 2587),
#  ('etc.', 2576),
#  ('model', 2574),
#  ('noticeable', 2569),
#  ('where', 2565),
#  ('control', 2563),
#  ('outfit', 2557),
#  ('tone', 2552),
#  ('non', 2548),
#  ('perfume', 2547),
#  ('shirts', 2546),
#  ('asking', 2546),
#  ('winter', 2539),
#  ('halloween', 2538),
#  ('blush', 2537),
#  ('mac', 2531),
#  ("won't", 2531),
#  ('❤️', 2529),
#  ('fully', 2528),
#  ('sticker', 2526),
#  ('[rm],', 2518),
#  ('time.', 2514),
#  ('place', 2514),
#  ('tags,', 2512),
#  ('sales', 2511),
#  ('proof', 2510),
#  ('background', 2505),
#  ('liner', 2504),
#  ('spray', 2491),
#  ('|', 2491),
#  ('except', 2489),
#  ('heel', 2485),
#  ('she', 2481),
#  ('designed', 2480),
#  ('slim', 2472),
#  ('detail', 2470),
#  ('buttons', 2470),
#  ('sweet', 2468),
#  ('questions.', 2465),
#  ('cosmetics', 2463),
#  ('white,', 2459),
#  ('someone', 2458),
#  ('nintendo', 2457),
#  ('perfectly', 2451),
#  ('going', 2449),
#  ('mix', 2448),
#  ('outside', 2447),
#  ('together', 2443),
#  ('cleaning', 2442),
#  ('xbox', 2442),
#  ('bags', 2437),
#  ('ones', 2435),
#  ('interested', 2434),
#  ('diamond', 2430),
#  ('follow', 2429),
#  ('attached', 2426),
#  ('holiday', 2422),
#  ('tags!', 2416),
#  ('rubber', 2415),
#  ('sheer', 2414),
#  ('candy', 2414),
#  ('such', 2413),
#  ('!!', 2410),
#  ('ever', 2409),
#  ('youth', 2408),
#  ('interior', 2407),
#  ('50', 2406),
#  ('factory', 2406),
#  ('takes', 2400),
#  ('type', 2393),
#  ('similar', 2390),
#  ('striped', 2389),
#  ('responsible', 2386),
#  ('1-2', 2383),
#  ('charm', 2383),
#  ('above', 2382),
#  ('month', 2379),
#  ('head', 2379),
#  ('tear', 2375),
#  ('n', 2374),
#  ('miss', 2365),
#  ('fresh', 2358),
#  ('blend', 2358),
#  ('glow', 2358),
#  ('approx', 2356),
#  ('usually', 2351),
#  ('tears', 2350),
#  ('buying', 2349),
#  ('leg', 2342),
#  ('think', 2340),
#  ('stains,', 2336),
#  ('drop', 2334),
#  ('friendly', 2333),
#  ('years', 2332),
#  ('packaging.', 2329),
#  ('say', 2324),
#  ('goes', 2322),
#  ('contains', 2322),
#  ('3.', 2320),
#  ('during', 2318),
#  ('pictures.', 2315),
#  ('opened.', 2313),
#  ('removable', 2312),
#  ('absolutely', 2310),
#  ('safe', 2306),
#  ('1.', 2303),
#  ('front.', 2300),
#  ('hollister', 2297),
#  ('doll', 2293),
#  ('beach', 2292),
#  ('mens', 2291),
#  ('mascara', 2291),
#  ('13', 2290),
#  ('kate', 2289),
#  ('stick', 2286),
#  ('k', 2283),
#  ('storage', 2281),
#  ('self', 2277),
#  ('ralph', 2276),
#  ('used!', 2276),
#  ('year', 2267),
#  ('exclusive', 2266),
#  ('25', 2263),
#  ('inseam', 2261),
#  ('resistant', 2259),
#  ('hardly', 2255),
#  ('s6', 2250),
#  ('clothes', 2250),
#  ('holder', 2249),
#  ('via', 2238),
#  ('lining', 2234),
#  ('flower', 2230),
#  ('wax', 2230),
#  ('crystal', 2228),
#  ('oversized', 2225),
#  ('firm,', 2225),
#  ('until', 2223),
#  ('lauren', 2219),
#  ('bundle!', 2219),
#  ('sides', 2217),
#  ('green,', 2214),
#  ('6.', 2213),
#  ('mail', 2211),
#  ('bundled', 2211),
#  ('it!', 2210),
#  ('pockets.', 2196),
#  ('camera', 2196),
#  ('approximately', 2188),
#  ('handle', 2186),
#  ('sandals', 2182),
#  ('color,', 2180),
#  ('item.', 2179),
#  ('shop', 2177),
#  ('handful', 2176),
#  ('use.', 2174),
#  ('formula', 2172),
#  ('sized', 2170),
#  ('search', 2165),
#  ('it,', 2162),
#  ('pure', 2161),
#  ('7.5', 2152),
#  ('boot', 2149),
#  ('priced', 2144),
#  ('tell', 2137),
#  ('8.', 2133),
#  ('looking!', 2132),
#  ('package.', 2130),
#  ('something', 2130),
#  ('print.', 2128),
#  ('free,', 2127),
#  ('flaw', 2124),
#  ('brushes', 2123),
#  ('metallic', 2119),
#  ('ask.', 2119),
#  ('llr', 2118),
#  ('ball', 2118),
#  ('rise', 2117),
#  ...]

# %% [markdown]
# ### __Important Note__:
#
# ### 前幾多的文字都算是 **stop words**。
#
# ## 統計:
# 1. 總共字數
# 2. 幾個單詞
# 3. 幾個只出現一次的詞
#
# 要loop Dictionary 可用 `items`

# %%
text = []
total = 0
appear_once = 0
for k, v in total_counts.items(): # k for keys, v for values
    text.append(k)
    total += v
    if v == 1:
        appear_once += 1
print("Total words: {}".format(total))
print("Unique words: {}".format(len(set(text))))
print("Numbers of appear once words: {}".format(appear_once))
# Out:
# Total words: 17793403
# Unique words: 367621
# Numbers of appear once words: 214911

# %%
text[:100] # list 為了省內存，列出前一百個
# Out:
# ['size',
#  '7',
#  '25',
#  'pcs',
#  'new',
#  '7.5"x12"',
#  'kraft',
#  'bubble',
#  'mailers',
#  'lined',
#  'with',
#  'wrap',
#  'for',
#  'protection',
#  'self',
#  'sealing',
#  '(peel-and-seal),',
#  'adhesive',
#  'keeps',
#  'contents',
#  'secure',
#  'and',
#  'tamper',
#  'proof',
#  'durable',
#  'lightweight',
#  'material',
#  'helps',
#  'save',
#  'on',
#  'postage',
#  'approved',
#  'by',
#  'ups,',
#  'fedex,',
#  'usps.',
#  'brand',
#  'coach',
#  'bag.',
#  'bought',
#  '[rm]',
#  'at',
#  'a',
#  'outlet.',
#  '-floral',
#  'kimono',
#  '-never',
#  'worn',
#  '-lightweight',
#  'perfect',
#  'hot',
#  'weather',
#  'rediscovering',
#  'life',
#  'after',
#  'the',
#  'loss',
#  'of',
#  'loved',
#  'one',
#  'tony',
#  'cooke.',
#  'paperback',
#  'in',
#  'good',
#  'condition',
#  '2003.',
#  '❤',
#  'bundle',
#  'save!',
#  'book,',
#  'death,',
#  'grief,',
#  'bereavement',
#  'shlf.sw.5.15',
#  'absolut',
#  'vodka',
#  'pink',
#  'iphone',
#  '6',
#  'plus',
#  'also',
#  'fits',
#  '6s',
#  'iphone.',
#  'these',
#  'are',
#  'made',
#  'flexible',
#  'rubber',
#  'material.',
#  'case',
#  'have',
#  'size:',
#  'free',
#  'shipping',
#  'two',
#  'vintage',
#  'cameo',
#  'pieces.']

# %% [markdown]
# ## `join` 的功能是？
# - PS : scroll down next cell 你會看到很多神奇符號，這就是raw data 真實樣貌

# %%
' '.join(text)[:10000] # 為了省內存，列出前一萬個
# Out:
# 'size 7 25 pcs new 7.5"x12" kraft bubble mailers lined with wrap for protection self sealing (peel-and-seal), adhesive keeps contents secure and tamper proof durable lightweight material helps save on postage approved by ups, fedex, usps. brand coach bag. bought [rm] at a outlet. -floral kimono -never worn -lightweight perfect hot weather rediscovering life after the loss of loved one tony cooke. paperback in good condition 2003. ❤ bundle save! book, death, grief, bereavement shlf.sw.5.15 absolut vodka pink iphone 6 plus also fits 6s iphone. these are made flexible rubber material. case have size: free shipping two vintage cameo pieces. 1. silver metal locket pendant filigree, green background ivory cameo. it is 2". 2. goldtone metal, mirrored gray pinback loop chain. shipping. price firm no trades box included 1yr warranty card dust cloth. metal: stainless steel finish: polished width: 12mm length: 8" can be adjusted smaller will not rust, tarnish, change colors or turn skin green. watch features quartz movement. face rose gold case. band gold. 100% authentic offers all new. 12 makeup brushes silicone beauty sponge authentic. retail [rm]. bramble rose. bnwt. comes box. --no shipping-- •no scratches• ◆all prices since mercāri charges 10% sellers fee every single transaction. ◆ask me to items fees only. i do discount bundles. ◆adult owned movies! #horror movie 27 waist 33 length decorated copper hardware studded pocket line, leg hem line. flair bottoms bronco styke cowgirl tuff co. super soft cropped sweat pant. - flaws. tags leggings lularoe nike small money back guarantee loot crate exclusive kill bill vol.1 men\'s socks fisher tea pot talks batteries 2 cups spoons 3 plates dessert shapes that fit yellow thing m boys xl michael jordan zip up jacket womens inseam 29 excellent fraying wear distressed look front \uf84cbrand new\uf84c ○ △free shipping△ ships same/next day. shipping!! make great gift... writing used, just imperfections cover(s). description scary stories set includes books: tell dark, more 3: tales chill your bones. three books written alvin schwartz drawings original illustrator, stephen gammell. publisher: scholastic language: english product dimensions: 7.5 x 5.3 inches children\'s kids toddlers spooky halloween best seller camping girls gift present birthday **message marble color you would like order** promotion: pick any only [rm]!! (get yourself another friend family!) sale pattern (color options: white/black/milky blue/pink) designed perfectly both & 4.7 available 6/6s models" design spec: easy access ports high quality tpu shell shock slim light weighto 360 grip fast shipping! our products shipped via usps first class real- time tracking! customer service we an experienced us satisfaction priority. work hard sure customers satisfied! respond quick so feel reach out questions! priced sell already discounted 15%!! order soon limited quantity!! 2t toddler 4pc joggers rips/holes grey blue red has spot near waistband ✨brand betsy johnson beautiful necklace ✨ ❤same day 6.5, women\'s 8 clear batman design. *case unopened. pictures used show how looks phone. donating tomorrow if doesn\'t sell. lowest price. this most comfortable maxi dress. it\'s stretchy. cross straps back. empire cut. navy black white tie dye ombré look. wore lot but tons left! from smoke pet home. home! kept hung up! ! flaws! ship usually within next :) please take my cheap prices. questions pleasw ask kendra scott bib necklace. was except pyrite morgan stones were swapped peach stones. there still morgan\'s, translucent allisons, slate allisons statement diy custom projects tarnish other flaws note. dri-fit long sleeve orange shirt. 1 vs pantie. color/style: as shown pictures. bag (only took pictures) may slightly different photos. *price firm! package sent mail. want priority, add more. ~~ check * remember don\'t combine listing. priority rates are: 0.5-3 lbs 3-10 10-20 sets toni new!! steps step 1: smoothing exfoliator 2: pore targeting tre ...

# %% [markdown]
# ### Important Note:
#
# ⚡❌⭕️◼️⚫❤✅✳️❇️⭐✔✔️☑️✨❗️❣️♥️❤️✴️⏺️⬅️⏬➡️♦️⛔♠️♣️⚠️◇♧♤▶ ......**more**
# - 超級多神奇符號emoji，以及莫名其妙的文字，夠骯髒的
#
# - 文字emoji 黏一起會被視為一個單詞
#    - Example:  ❤️iphone，會被視作一個詞彙，而不是 ❤️，iphone

# %% [markdown]
# # 練習時間：
# ## 所以各位學員的工作就是當一個稱職得清潔工
# ## 請寫一個Function，去手動把神奇符號給 取代 or 去除
# ### 此題沒有標準答案！
#
# - 您可以使用regex, or simply replace them.
# - Examle:
#
# ```import re
# text = re.sub('A','a', text)```
# - function name = `preprocessing`

# %%
# 練習題：

def preprocessing(text):
    text = str(text).lower()

    # Your code goes here
    # IP/OP both Pandas Series
    
    
    return " ".join(text.split())

# %% [markdown]
# ### preprocess 寫完後請執行這個Cell

# %%
train['item_description'] = train['item_description'].apply(lambda x: preprocessing(x))
test['item_description'] = test['item_description'].apply(lambda x: preprocessing(x))

# %% [markdown]
# ## 清除完後，請看
# 1. Total words
# 2. Unique words
# 3. Numbers of appear once words

# %%
start_time = time.time()
total_counts = Counter()
merge = pd.concat([train, test])
for i in range(test.shape[0]):
    for word in test['item_description'][i].lower().split(' '):
        total_counts[word] += 1
print('[{}] Sec Finished!'.format(round(time.time() - start_time,3)))

text = []
total = 0
appear_once = 0
for k, v in total_counts.items():
    text.append(k)
    total += v
    if v == 1:
        appear_once += 1
print("Total words: {}".format(total))
print("Unique words: {}".format(len(set(text))))
print("Numbers of appear once words: {}".format(appear_once))

# %% [markdown]
# ```
# print("Total words: {}".format(total))
# print("Unique words: {}".format(len(set(text))))
# print("Numbers of appear once words: {}".format(appear_once))
# ```
# ### 以上三項都要減少，本題沒有絕對答案，所以不提供答案。
